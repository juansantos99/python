# %%
import pandas as pd

# %%
base = pd.read_csv ("https://www.quandl.com/api/v3/datasets/MULTPL/SP500_DIV_YIELD_MONTH.csv?api_key=TBLavZNarehnwBsVjw8F")

# %%
base
# Out:
#      Trade Date  Index Value  High  Low  Total Market Value  \
# 0    2019-10-29         0.00   0.0  0.0                 0.0
# 1    2019-10-25      8029.22   0.0  0.0                 0.0
# 2    2019-10-24      7966.72   0.0  0.0                 0.0
# 3    2019-10-23      7889.47   0.0  0.0                 0.0
# 4    2019-10-22      7874.62   0.0  0.0                 0.0
# 5    2019-10-21      7940.33   0.0  0.0                 0.0
# 6    2019-10-18      7868.49   0.0  0.0                 0.0
# 7    2019-10-17      7942.14   0.0  0.0                 0.0
# 8    2019-10-16      7920.21   0.0  0.0                 0.0
# 9    2019-10-15      7942.85   0.0  0.0                 0.0
# 10   2019-10-14      7842.33   0.0  0.0                 0.0
# 11   2019-10-11      7843.87   0.0  0.0                 0.0
# 12   2019-10-10      7740.36   0.0  0.0                 0.0
# 13   2019-10-09      7690.53   0.0  0.0                 0.0
# 14   2019-10-08      7604.27   0.0  0.0                 0.0
# ...

# %%
base.Instrumento.unique()
# Out:
# array(['vara de pescar e botas', 'faca', 'arma de fogo',
#        'faca (peixeira)', 'soda caústica + força bruta',
#        'socos, pontapés e martelo', 'cabo de cortadeira',
#        'asfixia com fio elétrico + balde d"água', 'espingarda',
#        'cabo de vassoura, garrafa de vidro', 'canivete', 'envenenamento',
#        'Diazepan, instumento contundente, afogamento'], dtype=object)

# %%
base.Instrumento.value_counts()
# Out:
# faca                                            12
# arma de fogo                                    11
# cabo de cortadeira                               1
# soda caústica + força bruta                      1
# envenenamento                                    1
# canivete                                         1
# asfixia com fio elétrico + balde d"água          1
# espingarda                                       1
# socos, pontapés e martelo                        1
# faca (peixeira)                                  1
# Diazepan, instumento contundente, afogamento     1
# cabo de vassoura, garrafa de vidro               1
# vara de pescar e botas                           1
# Name: Instrumento, dtype: int64
